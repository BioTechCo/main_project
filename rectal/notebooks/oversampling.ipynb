# %% [markdown]
# # oversampling

# %% [markdown]
# ## 輸入檔案

# %%
from imblearn.over_sampling import RandomOverSampler
import pandas as pd
from collections import Counter
from sklearn.model_selection import train_test_split,StratifiedKFold,cross_val_score


file_path = '../result/GSE199057/train80/all_beta_normalized_train.csv' #exapmle
output_file_path = '../result/GSE199057/train80/all_beta_normalized_train'  #exapmle



# file_path = '../breast_liquid/NtoT/all_beta_normalized_breast_liquid.csv'
# output_file_path = '../breast_liquid/NtoT/all_beta_normalized_breast_liquid'
normal_number = 122
all_sample_number = 183

normalized_train = pd.read_csv(file_path)

X_train = normalized_train.iloc[:, 1::]
x = [X_train.iloc[:, i].values.flatten().tolist() for i in range(all_sample_number)]
y = [(0 if (i < normal_number) else 1) for i in range(all_sample_number)]

# %%
normalized_train
# Out:
#         Unnamed: 0         0       0.1       0.2       0.3       0.4  \
# 0       cg07881041  0.949957  0.952146  0.904001  0.954637  0.928165
# 1       cg03513874  0.937071  0.889363  0.843358  0.945049  0.913755
# 2       cg05451842  0.016502  0.006419  0.016312  0.022076  0.011215
# 3       cg14797042  0.962613  0.985027  0.964741  0.958186  0.967807
# 4       cg09838562  0.006557  0.007492  0.009818  0.002810  0.011285
# ...            ...       ...       ...       ...       ...       ...
# 711697  cg19812938  0.894460  0.878976  0.881958  0.896522  0.890799
# 711698  cg06272054  0.008978  0.004395  0.004080  0.004744  0.005768
# 711699  cg07255356  0.011516  0.009376  0.014099  0.016191  0.008926
# 711700  cg24220897  0.936086  0.921546  0.929182  0.897121  0.935147
# 711701  cg12325588  0.007245  0.007695  0.011690  0.001665  0.008831
#
#              0.5       0.6       0.7       0.8  ...      1.51      1.52  \
# 0       0.932608  0.924301  0.923104  0.927477  ...  0.749822  0.940172
# 1       0.857649  0.919933  0.909622  0.838915  ...  0.773122  0.759051
# 2       0.015107  0.049540  0.006533  0.016118  ...  0.015439  0.012183
# 3       0.982290  0.965621  0.974083  0.958924  ...  0.793072  0.965707
# 4       0.003184  0.014299  0.005508  0.009941  ...  0.005610  0.034703
# ...          ...       ...       ...       ...  ...       ...       ...
# 711697  0.872061  0.901984  0.908596  0.889975  ...  0.910865  0.877215
# 711698  0.008339  0.006556  0.005311  0.012396  ...  0.007236  0.008636
# 711699  0.013146  0.014820  0.003522  0.004258  ...  0.009114  0.012956
# 711700  0.924128  0.920541  0.937140  0.926174  ...  0.942277  0.940429
# 711701  0.006102  0.014344  0.009627  0.009264  ...  0.010725  0.005603
#
#             1.53      1.54      1.55      1.56      1.57      1.58      1.59  \
# 0       0.805832  0.756693  0.945328  0.923933  0.860106  0.928845  0.960072
# 1       0.809406  0.947666  0.897360  0.591877  0.960830  0.820967  0.902224
# 2       0.028709  0.011260  0.029149  0.013135  0.006605  0.018643  0.013003
# 3       0.777952  0.882774  0.934462  0.324543  0.977903  0.966190  0.971721
# 4       0.028405  0.012297  0.011081  0.005421  0.008825  0.004700  0.011022
# ...          ...       ...       ...       ...       ...       ...       ...
# 711697  0.886959  0.901002  0.894252  0.885177  0.909333  0.902665  0.908721
# 711698  0.005029  0.005122  0.009000  0.004814  0.004500  0.008904  0.003809
# 711699  0.016731  0.012227  0.010212  0.015228  0.003466  0.005697  0.001893
# 711700  0.927275  0.957908  0.930148  0.878596  0.825669  0.917967  0.944465
# 711701  0.017753  0.006174  0.011828  0.000505  0.007306  0.002808  0.001532
#
#             1.60
# 0       0.069006
# 1       0.062067
# 2       0.006081
# 3       0.956601
# 4       0.003067
# ...          ...
# 711697  0.837224
# 711698  0.013886
# 711699  0.023454
# 711700  0.953320
# 711701  0.011814
#
# [711702 rows x 184 columns]

# %% [markdown]
# ## RandomOverSampler

# %%
ros = RandomOverSampler(random_state=42)
X_train, y_train = ros.fit_resample(x, y)

print("過採樣後的類別分佈：", Counter(y_train))

oversample = pd.DataFrame(X_train).transpose()
oversample.columns = y_train
oversample.index = normalized_train.iloc[:,0]
oversample_sorted = oversample.sort_index(axis=1)

oversample_sorted.to_csv(output_file_path+"_oversample_random.csv")
# Out:
# 過採樣後的類別分佈： Counter({0: 22, 1: 22})

# %% [markdown]
# ## SMOTE

# %%
from imblearn.over_sampling import SMOTE

X_smote, label = SMOTE(random_state=42).fit_resample(x,y)


print("過採樣後的類別分佈：", Counter(label))

oversample = pd.DataFrame(X_smote).transpose()
oversample.columns = label
oversample.index = normalized_train.iloc[:,0]
oversample_sorted = oversample.sort_index(axis=1)
oversample_sorted.to_csv(output_file_path +"_oversample_smote.csv")
# Out:
# 過採樣後的類別分佈： Counter({0: 122, 1: 122})

# %%
oversample_sorted
# Out:
#                    0         0         0         0         0         0  \
# Unnamed: 0
# cg07881041  0.949957  0.952146  0.904001  0.954637  0.928165  0.932608
# cg03513874  0.937071  0.889363  0.843358  0.945049  0.913755  0.857649
# cg05451842  0.016502  0.006419  0.016312  0.022076  0.011215  0.015107
# cg14797042  0.962613  0.985027  0.964741  0.958186  0.967807  0.982290
# cg09838562  0.006557  0.007492  0.009818  0.002810  0.011285  0.003184
# ...              ...       ...       ...       ...       ...       ...
# cg19812938  0.894460  0.878976  0.881958  0.896522  0.890799  0.872061
# cg06272054  0.008978  0.004395  0.004080  0.004744  0.005768  0.008339
# cg07255356  0.011516  0.009376  0.014099  0.016191  0.008926  0.013146
# cg24220897  0.936086  0.921546  0.929182  0.897121  0.935147  0.924128
# cg12325588  0.007245  0.007695  0.011690  0.001665  0.008831  0.006102
#
#                    0         0         0         0  ...         1         1  \
# Unnamed: 0                                          ...
# cg07881041  0.924301  0.923104  0.927477  0.935669  ...  0.644990  0.793087
# cg03513874  0.919933  0.909622  0.838915  0.935467  ...  0.565574  0.786516
# cg05451842  0.049540  0.006533  0.016118  0.038684  ...  0.021037  0.021203
# cg14797042  0.965621  0.974083  0.958924  0.977678  ...  0.953071  0.973963
# cg09838562  0.014299  0.005508  0.009941  0.011887  ...  0.014648  0.015983
# ...              ...       ...       ...       ...  ...       ...       ...
# cg19812938  0.901984  0.908596  0.889975  0.878928  ...  0.897392  0.902431
# cg06272054  0.006556  0.005311  0.012396  0.003214  ...  0.005247  0.004645
# cg07255356  0.014820  0.003522  0.004258  0.021594  ...  0.020595  0.014122
# cg24220897  0.920541  0.937140  0.926174  0.920902  ...  0.924846  0.956301
# cg12325588  0.014344  0.009627  0.009264  0.004831  ...  0.007970  0.003420
#
#                    1         1         1         1         1         1  \
# Unnamed: 0
# cg07881041  0.932898  0.939335  0.764933  0.785068  0.785617  0.243787
# cg03513874  0.931714  0.779345  0.847313  0.581098  0.804814  0.255060
# cg05451842  0.017413  0.014292  0.021391  0.011055  0.028076  0.009630
# cg14797042  0.982536  0.963410  0.638995  0.767950  0.795198  0.969475
# cg09838562  0.017604  0.031771  0.017019  0.005599  0.026906  0.009751
# ...              ...       ...       ...       ...       ...       ...
# cg19812938  0.895908  0.878582  0.920996  0.873753  0.888982  0.867385
# cg06272054  0.005950  0.008489  0.006246  0.005086  0.005252  0.010990
# cg07255356  0.006085  0.012686  0.014574  0.014800  0.016009  0.024115
# cg24220897  0.895904  0.940107  0.916043  0.859563  0.929373  0.946021
# cg12325588  0.002221  0.005469  0.007123  0.013583  0.016503  0.014029
#
#                    1         1
# Unnamed: 0
# cg07881041  0.797899  0.876849
# cg03513874  0.936677  0.622096
# cg05451842  0.015168  0.007096
# cg14797042  0.894064  0.877406
# cg09838562  0.012031  0.008260
# ...              ...       ...
# cg19812938  0.899528  0.862359
# cg06272054  0.005969  0.004662
# cg07255356  0.011786  0.018081
# cg24220897  0.951844  0.907334
# cg12325588  0.007409  0.013464
#
# [711702 rows x 244 columns]

# %% [markdown]
# ## ADASYN

# %%
from imblearn.over_sampling import ADASYN


X_adasyn, label = ADASYN(random_state=42).fit_resample(x,y)

print("過採樣後的類別分佈：", Counter(label))

oversample = pd.DataFrame(X_adasyn).transpose()
oversample.columns = label
oversample.index = normalized_train.iloc[:,0]
oversample_sorted = oversample.sort_index(axis=1)
oversample_sorted.to_csv(output_file_path+"_oversample_adasyn.csv")
# Out:
# 過採樣後的類別分佈： Counter({1: 22, 0: 21})
